# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # base

# %%
metrics = np.load('./sign/metrics/M_mse_256_128_64_5000_peryton_sign_base.npy', allow_pickle=True).item()
metrics.keys()
train_loss = metrics['train_loss']
train_baseloss = metrics['train_baseloss']
train_aux1 = metrics['train_aux1']
train_aux2 = metrics['train_aux2']
train_wloss = metrics['train_wloss']
train_kl = metrics['train_kl']
train_r2 = metrics['train_r2']
train_RMSE = metrics['train_RMSE']
plt.figure()
plt.plot(train_loss)
plt.plot(train_baseloss)
plt.plot(train_aux1)
plt.plot(train_aux2)
plt.plot(train_wloss)
plt.plot(train_kl)
plt.legend(['train_loss', 'train_baseloss', 'train_aux1', 'train_aux2', 'train_wloss', 'train_kl'])

# %%
plt.figure()
plt.plot(train_kl)

# %% [markdown]
# # D loss

# %%
metrics = np.load('./sign/metrics/D_loss_512_256_128_5000_peryton_sign_base.npy', allow_pickle=True).item()
metrics.keys()
train_loss = metrics['train_loss']
train_baseloss = metrics['train_baseloss']
train_aux1 = metrics['train_aux1']
train_aux2 = metrics['train_aux2']
train_wloss = metrics['train_wloss']
train_kl = metrics['train_kl']
train_r2 = metrics['train_r2']
train_RMSE = metrics['train_RMSE']
plt.figure()
plt.plot(train_loss)
plt.plot(train_baseloss)
plt.plot(train_aux1)
plt.plot(train_aux2)
plt.plot(train_wloss)
plt.plot(train_kl)
plt.legend(['train_loss', 'train_baseloss', 'train_aux1', 'train_aux2', 'train_wloss', 'train_kl'])

# %%
plt.figure()
plt.plot(train_kl)

# %% [markdown]
# # aux1

# %% [markdown]
# ## aux1 早期迅速下降后稳定 帮助快速收敛  起到辅助重构损失的效果

# %%
metrics = np.load('./sign/metrics/M_mse_256_128_64_5000_peryton_sign_aux1.npy', allow_pickle=True).item()
metrics.keys()
train_loss = metrics['train_loss']
train_baseloss = metrics['train_baseloss']
train_aux1 = metrics['train_aux1']
train_aux2 = metrics['train_aux2']
train_wloss = metrics['train_wloss']
train_kl = metrics['train_kl']
train_r2 = metrics['train_r2']
train_RMSE = metrics['train_RMSE']
plt.figure()
plt.plot(train_loss)
plt.plot(train_baseloss)
plt.plot(train_aux1)
plt.plot(train_aux2)
plt.plot(train_wloss)
plt.plot(train_kl)
plt.legend(['train_loss', 'train_baseloss', 'train_aux1', 'train_aux2', 'train_wloss', 'train_kl'])

# %%
plt.figure()
plt.plot(train_aux1)

# %% [markdown]
# ## d loss

# %%
metrics = np.load('./sign/metrics/D_loss_512_256_128_5000_peryton_sign_aux1.npy', allow_pickle=True).item()
metrics.keys()
train_loss = metrics['train_loss']
train_baseloss = metrics['train_baseloss']
train_aux1 = metrics['train_aux1']
train_aux2 = metrics['train_aux2']
train_wloss = metrics['train_wloss']
train_kl = metrics['train_kl']
train_r2 = metrics['train_r2']
train_RMSE = metrics['train_RMSE']
plt.figure()
plt.plot(train_loss)
plt.plot(train_baseloss)
plt.plot(train_aux1)
plt.plot(train_aux2)
plt.plot(train_wloss)
plt.plot(train_kl)
plt.legend(['train_loss', 'train_baseloss', 'train_aux1', 'train_aux2', 'train_wloss', 'train_kl'])

# %%
plt.figure()
plt.plot(train_kl)

# %% [markdown]
# # wloss

# %%
metrics = np.load('./sign/metrics/M_mse_256_128_64_5000_peryton_sign_all.npy', allow_pickle=True).item()
metrics.keys()
train_loss = metrics['train_loss']
train_baseloss = metrics['train_baseloss']
train_aux1 = metrics['train_aux1']
train_aux2 = metrics['train_aux2']
train_wloss = metrics['train_wloss']
train_kl = metrics['train_kl']
train_r2 = metrics['train_r2']
train_RMSE = metrics['train_RMSE']
plt.figure()
plt.plot(train_loss)
plt.plot(train_baseloss)
plt.plot(train_aux1)
plt.plot(train_aux2)
plt.plot(train_wloss)
plt.plot(train_kl)
plt.legend(['train_loss', 'train_baseloss', 'train_aux1', 'train_aux2', 'train_wloss', 'train_kl'])

# %%
plt.figure()
plt.plot(train_wloss)
plt.legend(['train_wloss'])

# %%
metrics = np.load('./sign/metrics/D_loss_512_256_128_5000_peryton_sign_w.npy', allow_pickle=True).item()
metrics.keys()
train_loss = metrics['train_loss']
train_baseloss = metrics['train_baseloss']
train_aux1 = metrics['train_aux1']
train_aux2 = metrics['train_aux2']
train_wloss = metrics['train_wloss']
train_kl = metrics['train_kl']
train_r2 = metrics['train_r2']
train_RMSE = metrics['train_RMSE']
plt.figure()
plt.plot(train_loss)
plt.plot(train_baseloss)
plt.plot(train_aux1)
plt.plot(train_aux2)
plt.plot(train_wloss)
plt.plot(train_kl)
plt.legend(['train_loss', 'train_baseloss', 'train_aux1', 'train_aux2', 'train_wloss', 'train_kl'])

# %%
plt.figure()
plt.plot(train_kl)

# %% [markdown]
# # all

# %%
metrics = np.load('./sign/metrics/D_loss_512_256_128_5000_peryton_sign_base.npy', allow_pickle=True).item()
metrics.keys()
train_loss = metrics['train_loss']
train_baseloss = metrics['train_baseloss']
train_aux1 = metrics['train_aux1']
train_aux2 = metrics['train_aux2']
train_wloss = metrics['train_wloss']
train_kl = metrics['train_kl']
train_r2 = metrics['train_r2']
train_RMSE = metrics['train_RMSE']
plt.figure()
plt.plot(train_loss)
plt.plot(train_baseloss)
plt.plot(train_aux1)
plt.plot(train_aux2)
plt.plot(train_wloss)
plt.plot(train_kl)
plt.legend(['train_loss', 'train_baseloss', 'train_aux1', 'train_aux2', 'train_wloss', 'train_kl'])

# %%
plt.figure
plt.plot(train_kl)
plt.legend(['train_kl'])

# %% [markdown]
# # aux

# %%
metrics = np.load('./sign/metrics/M_mse_256_128_64_5000_peryton_sign_aux1.npy', allow_pickle=True).item()
metrics.keys()
train_loss = metrics['train_loss']
train_baseloss = metrics['train_baseloss']
train_aux1 = metrics['train_aux1']
train_aux2 = metrics['train_aux2']
train_wloss = metrics['train_wloss']
train_kl = metrics['train_kl']
train_r2 = metrics['train_r2']
train_RMSE = metrics['train_RMSE']
plt.figure()
plt.plot(train_loss)
plt.plot(train_baseloss)
plt.plot(train_aux1)
plt.plot(train_aux2)
plt.plot(train_wloss)
plt.plot(train_kl)
plt.legend(['train_loss', 'train_baseloss', 'train_aux1', 'train_aux2', 'train_wloss', 'train_kl'])

# %%
plt.figure()
plt.plot(train_kl)
